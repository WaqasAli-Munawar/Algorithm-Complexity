# %% [markdown]
# In the previous file, we learned how to analyze the time complexity of an algorithm.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# In this file, we will see another kind of time complexity: constant time complexity. We will also learn the core operations that a computer can perform and how a computer structures data into its memory.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The way of modeling the time complexity in the previous file assumed that each line execution takes a constant amount of time. In other words, each line of code is somewhat a constant time algorithm.
#
# In this file, we are going to learn that this assumption does not necessarily hold all of the time. We will see which operations a computer can perform in constant time and which ones it cannot.
#
# let's recap what we've learned in the previous file.

# %% [markdown]
# **Task**
#
# A function that computes the average value of a list is provided to analyze its time complexity.
#
# ![image.png](attachment:image.png)
#
# **Answer**

# %%
def average(values):
    average = 0
    for value in values:
        average += value
    return average / len(values)
# The line count for this function is the following:
"""
def average(values):
    average = 0                  # 1
    for value in values:         # N
        average += value         # N
    return average / len(values) # 1
"""
# Adding all terms together we get: 
# 1 + N + N + 1 = 2N + 2
#
# Coefficients are [2, 2]
#
# Drop low terms: 2N + 2 -> 2N
# Drop multiplicative constants: 2N -> N = O(N)
#
# Order is O(N)

coefficients = [2, 2]
order = "O(N)"

# %% [markdown]
# Above, we learned that a constant-time algorithm is an algorithm whose time complexity does not depend on the data. In terms of Python, these are functions whose execution time does not depend on the input. The `max_two()` function that computes the maximum between two given values is one such example:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Despite the fact that `sum_1000()` performs a lot more line executions than `max_two()`, its total number of line executions is constant.

# %% [markdown]
# **Task**
#
# Three functions are provided to identify whether or not it has constant time complexity.
#
# `def function1(N):
#     for i in range(N):
#         print(i)`
#
# `def function2():
#     for i in range(100000):
#         print(i)`
#
# `def function3(N):
#     for i in range(100000):
#         print(i)`
#
# **Answer**

# %%
def function1(N):
    for i in range(N): # N
        print(i)       # N
# function1 is O(N)

def function2(): 
    for i in range(100000): # 100000
        print(i)            # 100000
# function2 is O(1)

def function3(N):
    for i in range(100000): # 100000
        print(i)            # 100000
# function3 is O(1)
        
constant1 = False
constant2 = True
constant3 = True

# %% [markdown]
# As we mentioned earlier, we've assumed that all line executions take constant time. Let's see that this is not the case and refine our model.
#
# Consider the function `min_max2()` from the previous file. Recall that the function calculates the minimum and maximum values of a given list:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The total number of line executions is three. According to what we learned so far, the complexity would be O(1). This contradicts the complexity O(N) that we obtained in the previous file. The problem is that we cannot treat function calls as constant-time operations.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# Our goal is to analyze the time complexity of the provided `average()` function. This function uses two other functions `sum_values()` and `num_values()` that are also provided. A partial time complexity analysis is provided.
#
# ![image.png](attachment:image.png)
#
# **Answer**

# %%
def sum_values(values):
    total = 0            #
    for value in values: #
        total += value   # N
    return total         #

def num_values(values):
    total = 0            #
    for _ in values:     # N
        total += 1       #
    return total         #

def average(values):
    value_sum = sum_values(values)  #
    num_values = num_values(values) # N
    return value_sum / num_values   # 1
# Complexity analysis

def sum_values(values):
    total = 0            # 1
    for value in values: # N
        total += value   # N
    return total         # 1

def num_values(values):
    total = 0            # 1
    for _ in values:     # N
        total += 1       # N
    return total         # 1

def average(values):
    value_sum = sum_values(values)  # N
    num_values = num_values(values) # N
    return value_sum / num_values   # 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# As we can see, this has complexity O(N) and not O(1) , even though we don't explicitly see a function call. Therefore, when analyzing the time complexity of an algorithm in Python, we need to be on the lookout for hidden function calls.
#
# The following general principle will help us not to miss some hidden complexities.
#
# * An algorithm cannot have a complexity lower than the size of its output.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The above examples are common cases where we might find hidden function calls in Python. However, there are numerous others, too many for us to list here.

# %% [markdown]
# **Task**
#
# Six lists created using list comprehensions and five possible time complexities. Our goal is to identify the correct complexity of creating each list as a function of N and M.
#
# **Answer**

# %%
N = 10
M = 20

list1 = [_ for i in range(0)]
list2 = [i for i in range(3)]
list3 = [i * i for i in range(M)]
list4 = [[i + j for j in range(M)] for i in range(N)]
list5 = [min(list4[i]) for i in range(N)]
list6 = [i for i in range(1000)]

complexity1 = 'O(1)'
complexity2 = 'O(N)'
complexity3 = 'O(M)'
complexity4 = 'O(N + M)'
complexity5 = 'O(N * M)'

# Example answer for list1
answer1 = complexity1
answer2 = complexity1
answer3 = complexity3
answer4 = complexity5
answer5 = complexity5
answer6 = complexity1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In general, an algorithm takes some data and computes something out of it. In order to process data, we need a way to store and access that data into the computer memory. For this reason, it is important to understand how more complex data can be created, such as lists, strings and dictionaries. To do so, we need to understand how a computer can allocate memory.
#
# We have learned that when we declare a variable in Python, the computer will allocate a position in its memory to store the value of the variable. The name that was used for that variable can then be used to access that value. For instance, imagine that we declare a variable named `result` with value `20`, like so:
#
# `result = 20`

# %% [markdown]
# ![image.png](attachment:image.png)
#
# When a computer allocates memory for a variable, it can either allocate a single location or a continuous range of locations. The above figure illustrates an example where a single location is allocated. A continuous range of locations is called an **array**.

# %% [markdown]
# Imagine that we create a list, as shown below:
#
# `values = [20, 13, 8, 11, 42, 4]`
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Above, we learned how lists are represented with arrays inside the computer memory. Arrays are a rigid data structure whose length cannot be increased. For this reason, to append an element to a list, we need to allocate a new array of bigger length and copy all elements previously in it together with the new element that we want to add.
#
# If not implemented carefully, this will result in an O(N) time complexity for the `list.append()` method. This is because, at each insertion, we'll need to copy all of the previously added elements.
#
# There is a trick to overcome this. Instead of allocating an array with the exact number of elements in the list plus one, we create a bigger array, leaving some unused positions in the end. We also keep a variable that points to the first empty position in the array. Then, when we want to add a new element to the list, we add it to the first unused position in constant time.
#
# However, as we keep adding elements, we will eventually fill all positions. At this point, we need to resize the array. Instead of increasing the length of the new array by one, we make it bigger than necessary. In this way, we will be able to add new elements in constant time for a while, before having to do another resize.
#
# Imagine that we execute the following code:
#
# `values = []
# values.append(0)
# values.append(1)
# values.append(2)
# values.append(3)
# values.append(4)`
#
# One resize strategy is to create a new array with double the length of the original whenever it becomes full. Here is an illustration of the underlying array used to store the values `list`:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# As we can see, by using more memory, this process reduces the number of times we will need to resize the array. Let's analyze what we lose in terms of memory and what we gain in terms of time complexity with this solution.
#
# To answer the memory question, observe that, since we double the array capacity when it becomes full, it means that after the resize, at least half of the array is full. Therefore we use at most double the required memory.
#
# To analyze the time complexity, we need to take another look. If we look at a single `list.append()` we still have O(N) complexity since, in the worse case, we need to resize the array. However, let's look at the total cost of adding N elements rather than a single element.
#
# Let's do this experimentally. To do our experiment, we will pretend that we add elements to a list and keep track of the number of elements in the list, as well as the length that the underlying array would have. Given these two parameters, we can compute the cost of adding an element to a list using the following function:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The first thing that we check is whether we need to resize the array. This happens when the length of the array and the list are the same. In this case, the cost is essentially O(array length). Otherwise, it is done in O(1).
#
# The experiment will receive the number of elements to add as a parameter. Then, it will simulate adding elements to the list by keeping track of the list and array sizes. At each iteration, we will compute the cost with the above function and add it to the total cost. Remember, we want to evaluate the total cost of adding N elements.

# %%
def append_N_list_cost(N):
    array_length = 1 # Initially the array will have length 1
    list_length = 0  # Initially the list has 0 elements
    total_cost = 0   # This variable will keep track of the total cost
    for i in range(N):
        cost = append_cost(array_length, list_length)
        total_cost += cost
        # Update the array and list lengths
        if array_length == list_length:
            array_length *= 2
        list_length += 1
    return total_cost

# %% [markdown]
# Executing `append_N_list_cost()` will return the estimated cost of adding N elements to a list.

# %% [markdown]
# **Task**
#
# Our task is to run this experiment from a range of values of N and plot the results to see how this is growing.
#
# 1. Initialize an empty list named `costs`.
# 2. Use a for loop over `range(5000)` using a variable named `N`. For each value of `N`:
#     * Call `append_N_list_cost()` by passing the current value of `N` as an argument. Assign the result to a variable named `cost`.
#     * Append the result to the costs list that we've created.
# 3. Use the provided `plot_costs()` function to plot the `costs` list.
#
# **Answer**

# %%
import matplotlib.pyplot as plt

def plot_costs(times):
    plt.plot(times, label='append cost')
    plt.ylabel('cost')
    plt.xlabel('N')
    plt.show()
    
def append_cost(array_length, list_length):
    if array_length == list_length:
        return array_length
    return 1

def append_N_list_cost(N):
    array_length = 1 # initially the array will have length 1
    list_length = 0 # initially the list has 0 elements
    total_cost = 0 # this variable will keep track of the total cost
    for i in range(N):
        total_cost = append_cost(array_length, list_length)
        total_cost += cost
        # update the array and list lengths
        if array_length == list_length:
            array_length *= 2
        list_length += 1
    return total_cost


costs = []
for i in range(5000):
    cost = append_N_list_cost(i)
    costs.append(cost)
plot_costs(costs)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# It's not clear at first how this function is growing. It grows linearly, but then it sometimes jumps. These jumps correspond to the moments where we needed to double the array length. The next figure shows the same plot together with the functions 2N and 3N :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In terms of execution time, having amortized complexity O(1) will yield the same results as if the complexity really was O(1). We can think of this analysis as distributing the few costly operations amongst all executions of the method.
#
# How about other list methods? Here is a table with the time complexity of the most common list methods:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# Two functions are provided. The `add_with_append()` creates a list using the `list.append()` method, while `add_with_insert()` uses `list.insert()`. Our task is to time both functions to see that appending is much more efficient than inserting.
#
# ![image.png](attachment:image.png)
#
# **Answer**

# %%
def add_with_append(N):
    values = []
    for i in range(N):
        values.append(i)
    return values

def add_with_insert(N):
    values = []
    for i in range(N):
        values.insert(0, i)
    return values

import time

start = time.time()
add_with_append(50000)
end = time.time()
time_append = end - start

start = time.time()
add_with_insert(50000)
end = time.time()
time_insert = end - start
    
print(time_append)
print(time_insert)
# Out:
# 0.007991313934326172
# 1.083399772644043

# %% [markdown]
# As we saw above, inserting is much slower than appending. We obtained the values:
#
# `0.007476806640625  # Time with list.append()
# 1.3033199310302734 # Time with _list.insert()`

# %% [markdown]
# We might have gotten slightly different values, but in any case, the second value should be much larger than the second. Dividing 1.303 by 0.007 we get 186, meaning that `list.append()` was 186 times faster than `list.insert()` to add 50,000 values.
#
# We mentioned that computers can do addition, subtraction, multiplication, and division in constant time.
#
# Computer processors are designed to manipulate fixed bit length numbers very efficiently. However, we've already learned that Python does not use fixed bit length integers and that numeric values can grow as large as the computer memory allows.
#
# We learned, in this file, that computers cannot manipulate arbitrarily large amounts of information in constant time. Since the size of numbers in Python can grow as large as the computer memory allows, we conclude that arithmetic operations cannot be performed in constant time in Python.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# The variable `pairs` contains a list of pairs of integers with an increasing number of digits. Each pair contains two integers with the same number of digits. In the first pair, the numbers will have 1 digit, in the second pair, they will have 2 digits and so on.
#
# The idea of this experiment is to measure the time required to multiply each pair of integers and use the provided `plot_times()` function to plot these times to see that they are indeed increasing.
#
# **Answer**

# %%
pairs = [(3, 5),
 (73, 98),
 (175, 967),
 (4196, 4917),
 (39513, 31893),
 (125832, 846781),
 (8578541, 5495644),
 (66745978, 48629483),
 (192985863, 321846841),
 (5932992992, 3944445511),
 (34549655924, 84546724993),
 (489827388993, 953415635411),
 (3222624238443, 9986646235274),
 (83112312223688, 87972197936816),
 (275642256581448, 217328448937274),
 (8496452495386688, 4571261474319539),
 (92557162321176783, 72987693654871596),
 (979675152153644255, 974126462635241461),
 (6194231573963219439, 2789952542359335919),
 (82532917954112383364, 21563988878424497613),
 (998348823186736431795, 853183738168364817962),
 (8379381597269461388368, 7752665332759335941261),
 (63249483197473977371413, 46882515575562328123453),
 (452378826744165382299642, 143817759132766393257961),
 (3294764622785711841745874, 7771752752652789823962749),
 (16644111381141123792159552, 22349482346481392166142454),
 (856984874524275998859311887, 131446951234578674764665756),
 (7379693926244945862561377111, 1121292321332773288534482141),
 (66338868925469229697768722314, 35782696377739191872922561321),
 (276393539676465241174997211387, 196826997266663913785351111618),
 (1666257532972131317632144187859, 4838323744749134149556943658714),
 (89842133141375265926912638336524, 22853829899447544635396832814772),
 (544435952967378396567756517178867, 999127623411117422647931822778949),
 (2136476161613771673351734911372277, 3244855296988517384526562625674275),
 (12871369766336145784336954864523282, 53364983641118946841845483165358453),
 (464695368489693864426219436979155183, 416798896836459825163953377682725471),
 (9415893478733647765742815869496627324,
  5454845183428767762179535618489848373),
 (17282451311646457938469964269974927883,
  45115113851921228414858141649732421475),
 (223857954453644685547152452466227341857,
  842357515465585275959841274423819431274),
 (8932745344872812327921442458889123991911,
  4226529572832292846175825432183137456349),
 (68466447957652977511234431641463281937597,
  86759241952871535184951492974223182288425),
 (491224933238342483665764113321765443141998,
  368548878174737862631697922531993751445783),
 (5959611527755274629936941741328982164256363,
  7251232284921793665382275664448927876822766),
 (28748334346969713759512328935894389235984393,
  32111431564956418281194243684212416617998949),
 (193651418614286122396723889884534897631267716,
  714839362852139439471652737463879649295195845),
 (7747394295782636317124789659832591275841933325,
  9853322354587996626549236974682178342953634461),
 (56511396416192662856139941367526977953953375314,
  51217813335346542148588763713215717775986921443),
 (468851993858511765375654744238744765861826276247,
  473541884131322451939834536243159451788191246584),
 (3361613763859194576519165981114953217419685321766,
  4445591391539665217187896283657255511276488242148),
 (92835464562244599979748248994254449682926161975488,
  31568959255374257739428719375554226932865944435276),
 (478722379719117735194543983768692132115668256891822,
  116875793516679268232242193477517179589841992636414),
 (5575314972372413765857971646145489849713372186197472,
  9563311757623187223719652837145334947848539314498274),
 (75731561798881367365187768152922255113151251553946373,
  14738817472429868533952294541684541858651818989215814),
 (819466948384889838945839367694661659681516364289984598,
  526975287519793288732897361611542588758443164476774636),
 (7453521994385678619886449457338938698722679958814262448,
  6617933587857739516781381423953231241293488545319791837),
 (62923843239389263491378424962259264653942634344287137795,
  74881129113273495492343832796149651497355169793322347739),
 (283685945596595745545717747563852876797482215487643279359,
  116294916496156669489422426686514126959477149743419173782),
 (7324339339891722291529325755834283374439338166831243544686,
  9647657922613656187418313647848354252216118417349787642715),
 (86128888413367949541583765652233593553715725694487233163429,
  44741997374553984198239397534921839594166985347392371877792),
 (621264194396528596716787241429287452173855551599445877498781,
  253896663612461129516742838912449987129731986243896249294338),
 (1889681286642598791598387555337481419499664722842499628331113,
  9411553322158615528789883634442291528221142578142576684421934),
 (78464737854733798912484564865161428725714695856274555181552552,
  99487848619624311432478632654421667947416115475376499474762546),
 (978738895865976346723654497621562269467973949714989956634941536,
  949548481998945454936377126665276258929266736991814152338986355),
 (5486757236265559364479952689744371445698424146451218126669445381,
  3381923155854823298973637276511587858144297725888899416181789825),
 (17136946614275183454425414789161428171782517999729468932591473428,
  73492947571667566621653587557995443654444937596355624522552383785),
 (149658939473457127373652314583482694683985413564913288464497345442,
  799392235864653291975545235924184866225155538137337348358357355744),
 (8283795754436892552694127126711563719751593981419752341121449816789,
  9744283485827671674368333175313968637683585256114282549633477862734),
 (58445223186882181815984586941553338527182331852859722377451733681986,
  14626538152561224638126556239791668411258512721168965733188661584563),
 (536686817169577448985638368194349869213994183665281226578999538462637,
  787754131657259651655526148466225298613721565532363269125787633224234),
 (2621934536512262847869241126764617388444355785676371835416274287444754,
  7465192989649196373786644746358944277898165214995963315415119459873162),
 (67725479365162649523587858339455178826298456378495764258558194132976369,
  55349137643245542579995578637731796333785737496862556329711253662599862),
 (757899489783213472521386286128213413424152914196233853397438917518739883,
  189757957321398561134548721384985757944355142118431472447395974852623711),
 (1527144179737644723926174856878954316442119484783277578181212619922351293,
  2967575184456175537569623774383585642483417978595758836819418334257939237),
 (17228494661226133553839322294529872318397585737513269142492258485393734115,
  76868567665321293628675585561636334966783564471655579512216451618485936846),
 (696655211719138235747679761729989175141421622922582266264824761739262664823,
  867728268584297788884653685739343992349884255732655826213476749592446837377),
 (9351221592164637528611368675146758269165582537495514964926564535824824494337,
  7584911225267911878424762416189922948811818745869419532867627688576519959438),
 (96128124454782776272272947459614553591313415695741286349259184637478854844696,
  17826227142947136123633211664723547736325436367194835392284521141663231764619),
 (417592298424763661535251418355274531831667692616292528952542831548618912136321,
  217944973417388216282584438153862966292381321733696964495635894816578164456981),
 (7315654679977953345611147498528536614959679582735318987552556836826377594143887,
  7973326361378757632149188512628876982842335876827521415862119563548735676184148),
 (61945995947157373389241457258749873726956887699695553295777911389757843435412472,
  19154676833288655336161336586178974111324831479984224348961983411859194872271726),
 (885195175321194259567791824882638413143446983179663295544267656494478184241182317,
  716526827196743729892539921795584999299147677679992584214866622814547511532823848),
 (1932872755369112947138472971577759262276243913668966422342616479996749932581936593,
  7934621739951624181528953514661895783548367323989637636145191933229861213964362866),
 (23668622146458233639415687776351152223143499894583123577256225474856713535815589728,
  78121991526322577863193629167127127949996933112685632357726766181337872896168275998),
 (584916661639523836423984886222425894153666499276511394972912264442128388582316651488,
  251829668782532934343213762623418335757741121112894344777561237578445527563359557668),
 (8553833429118116398718647132457532589694464321281696933345145667912988833469529468368,
  8116681569956467732719563219574645344957634979374278665684149572699458223744465598433),
 (53421132735872735782364972812872336756218299779116355369977369862225528956889937418423,
  97928926135628917318417699618793859278716229851387215553612498672589871652194292965972),
 (632779523275744622844151863312153596941311865612166388245735258859654358515269337835725,
  868257536749848265947287634634796248879726666436861498331257221881173359311646857947686),
 (6954754757157166195961181465869171871145741431672585128741872353726127423329583357878789,
  2319756521499413498379157828716527552771852374926467217327572697123662551523772181497483),
 (85571957382518424698873794456716284239774899191865763146785626771544759735267852252468744,
  64211774624829182325819627391535727151354927441783551215157699113617344265838521583436277),
 (514181189937723198184593823559531369564437138273651696193481539378952541243527895346992428,
  241527736434842379196549619877734293962363815486661215445512521722586673843986247666839586),
 (9713954895623769321162454987181929695318484953577845516151261819665745326445297585894799812,
  1142299594485917849425331875416684312223212675663865169778914322757983343979355967792491349),
 (59712453983148525198181234299283213392894264277552679973594924588619579656278474632284842852,
  83953463691173661576389644449156653811161447183651116426742683263324698933993213169979294538),
 (919153395915869867849137621441223688725731174464966115245816519884944141948971926867668483537,
  326834996945568677171314971441466678474255575539256453187883865757258252175726273514276927949),
 (6435523944617674717955573986219936312319498353422527968111648633786393811928743667951132332494,
  2674555111623594478746565462682195481391548134991218876692899547528328674653629156785467367335),
 (28962379613724851767221337192867739215763345647997899189377668535377179491443442776911867472912,
  68538611218764546971647893118522129972476769685792665333882545196276245876857448967393846288893)]

# %%
import matplotlib.pyplot as plt

def plot_times(times):
    plt.plot(times)
    plt.ylabel('multiplication runtime')
    plt.xlabel('number of digits')
    plt.yscale('log')
    plt.yticks([])
    plt.show()


import time

times = []
for x, y in pairs:
    start = time.time()
    z = x * y
    end = time.time()
    times.append(end - start)
plot_times(times)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   import sys

# %% [markdown]
# Above we plotted the times of multiplying integers with an increasing number of digits. Here is what the plot looked like:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# But how much does it cost to concatenate two strings? We've learned that it cannot take constant time since we are producing an output that does not have a constant length.
#
# Under the hood, strings, just like lists, are implemented using arrays. The array has one position for each character. Imagine we have two strings like below:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# A list named `random_strings` that contains a list of randomly generated strings is available.
#
# Two functions are also provided. The `concat_with_add()` function concatenates strings using the `+` operator while `concat_with_join()` uses `str.join()`. Our task is to time both functions on the provided `word_list`.
#
# **Answer**

# %%
random_strings = ['tdrxvpaiut\n',
 'ltzxjepsgl\n',
 'zaxiqsdzpi\n',
 'naprvwggts\n',
 'rhorhifeqf\n',
 'fdfhsysihx\n',
 'sywwancqku\n',
 'jlmjnvsykr\n',
 'tlwwqxyxip\n',
 'xluvdygihg\n',
 'mdkmcphljb\n',
 'dscyhlkbal\n',
 'rhyjdyfgsw\n',
 'rojlnadaac\n',
 'uqikveceef\n',
 'fllsvnebbw\n',
 'aywvyxgpsc\n',
 'vrjhlzhgby\n',
 'qqvcnkqhxd\n',
 'jeytnamqhu\n',
 'fgclccpqvf\n',
 'uyfzkpdzzn\n',
 'uijjbzfqjn\n',
 'wvtpjawdqo\n',
 'xcnavujzjy\n',
 'rltprzbqlf\n',
 'qfcguolbpx\n',
 'wfmbmdxejv\n',
 'fjrugiavqv\n',
 'asxaulvbjr\n',
 'obfglzvqkv\n',
 'ifnfxwsguv\n',
 'hcrzxxdsyg\n',
 'hjvmifvczv\n',
 'zqhbredvox\n',
 'wurblqlzec\n',
 'rcldjtjxqz\n',
 'eowagptobi\n',
 'ljfuypicwl\n',
 'jiuhsetjri\n',
 'rorzizbnej\n',
 'ylhvajcqko\n',
 'zwmkbinjrs\n',
 'wnucztamrk\n',
 'pxzlzojpsl\n',
 'vcsvzjjczu\n',
 'irypopsulr\n',
 'ygmkpeyqpp\n',
 'jnuqtndgcf\n',
 'mgohkuzsmv\n',
 'ifhnyxhiut\n',
 'ovkikgwsav\n',
 'qaijkkdppn\n',
 'ttjxfqqlyv\n',
 'lczbtfions\n',
 'ohfyfxgchu\n',
 'zysmskszjr\n',
 'cfealjemgt\n',
 'wwcbrhwcrq\n',
 'fggbcdbipq\n',
 'kkmhkskmnw\n',
 'nawqxsdrnp\n',
 'kfefixeeae\n',
 'bvlpjmzjmt\n',
 'umibelrnzg\n',
 'qlzhzrwmrk\n',
 'vdnkhjvhrn\n',
 'zpkshbdbql\n',
 'xngnoiitms\n',
 'xvewiwognn\n',
 'itvlhuqvuu\n',
 'ebxwxxigiy\n',
 'ibbrzpjzcg\n',
 'sggdzjslaw\n',
 'ufmcbneket\n',
 'fjvduirale\n',
 'duwtoucrtz\n',
 'xnikdudixk\n',
 'heamvueriv\n',
 'rchbkqxhpw\n',
 'ibkutfdmmv\n',
 'fhosoemjeo\n',
 'epyazarrng\n',
 'pvragdfucp\n',
 'ffrpfeujme\n',
 'ozbuwziuby\n',
 'qpgctqthng\n',
 'hzjquxlevy\n',
 'eharrgtuiu\n',
 'kvngalbyez\n',
 'crpmcpgtbb\n',
 'gwpsulqxuv\n',
 'oeczidsfaf\n',
 'jtbucipwif\n',
 'qsrownbuuc\n',
 'bhsxmbqrqy\n',
 'ungryumoox\n',
 'hewtuprevl\n',
 'tluuygrklf\n',
 'rimtzcfiqn\n',
 'xnojykkzxa\n',
 'guvkatyqgf\n',
 'hsooilodek\n',
 'godhpulcke\n',
 'kliqzzwfma\n',
 'utlakekzlu\n',
 'kkjtmkvucf\n',
 'aenasrfywt\n',
 'gsegwrtzvv\n',
 'tsfxateygd\n',
 'svaytzdbjx\n',
 'nkwtzeqnuc\n',
 'omzrbmzbra\n',
 'jgauqahfpi\n',
 'wdxiakkdzz\n',
 'bioqzckccv\n',
 'pkesocipnh\n',
 'jzxknqprfa\n',
 'lrzqmxslqw\n',
 'ojugniexiw\n',
 'mjbkxdeyzd\n',
 'qlrnhqtyeg\n',
 'aobeyongxg\n',
 'zeizptscyw\n',
 'lxoijwozpi\n',
 'qgywnaxcxw\n',
 'sdjoddfskm\n',
 'xlsybchyqm\n',
 'ireaukjdmb\n',
 'unutzgcbby\n',
 'mwnuuyxgtq\n',
 'zhowgnwvsp\n',
 'zbxexdrbug\n',
 'lhdwlqxzfo\n',
 'jjibsshjfm\n',
 'gyolmcfynu\n',
 'hlnadjcekp\n',
 'ggizrukzsq\n',
 'lwpwixqnso\n',
 'bljocdhseg\n',
 'ntfbcexnrp\n',
 'yyjcsguudp\n',
 'sesqsjaxva\n',
 'gexenaplbq\n',
 'bqcxlmnlii\n',
 'lrpxzhhxwx\n',
 'wjvkosloki\n',
 'ormkqlwsme\n',
 'sanzyiqijb\n',
 'njawjqpokt\n',
 'mzkxhnfkzp\n',
 'ldpfpzajni\n',
 'lccydriopi\n',
 'ivtrgbfddb\n',
 'lteagtcxlz\n',
 'qtuzvrtsfa\n',
 'clsryyxqlv\n',
 'akxgcrctqx\n',
 'iqzlijgmth\n',
 'wqiuruyzmk\n',
 'krtrevkvjv\n',
 'rjhtxhmpbz\n',
 'mruqaqliht\n',
 'vsyvucpaun\n',
 'byzrvhsimi\n',
 'evyyjgbgwl\n',
 'yshbonoxru\n',
 'hkhnmspgkd\n',
 'jpqjuvtfvb\n',
 'ydxciaoalu\n',
 'yyxkjjealc\n',
 'zadbkwsrai\n',
 'dpgzyjmvjs\n',
 'lpssoggdbx\n',
 'hecgpgirxv\n',
 'khhnsdqhwp\n',
 'vigopylumz\n',
 'gxmwinjxso\n',
 'iqcmfkrtyc\n',
 'ygosqbwspc\n',
 'rtoenmlmyk\n',
 'cmppypjryx\n',
 'eajlmntnfs\n',
 'rgmawaqywo\n',
 'kplcbzwqun\n',
 'vxoidticeg\n',
 'gefnankthc\n',
 'oepgjqfbyb\n',
 'tydinyxrvj\n',
 'uxqqbkhmzp\n',
 'xszlaaikft\n',
 'mbnjlelzbg\n',
 'vrsdxndfee\n',
 'qdevutrwpg\n',
 'bzjcynkbic\n',
 'xnjcjptvgv\n',
 'xvuqtrtbxr\n',
 'tdkwyzoycp\n',
 'gklhivsgpy\n',
 'ltkeqzyany\n',
 'bwfxixwrvg\n',
 'waubwutsaa\n',
 'tndtpsasiz\n',
 'skytezsasx\n',
 'alfraiuxyl\n',
 'odeehlhryu\n',
 'idiyrdxdls\n',
 'mslbxrfiaz\n',
 'obafizmlyv\n',
 'rehbgthfat\n',
 'vqfvkvvcwm\n',
 'oojvodivdf\n',
 'chbespatie\n',
 'bbcdejjrny\n',
 'iliswouyna\n',
 'qxeidlydow\n',
 'xbfbzrvjap\n',
 'ozlkmboynd\n',
 'onybvxioej\n',
 'lforetkyht\n',
 'sbirzhikql\n',
 'qqooctjnlw\n',
 'tgespkkwxk\n',
 'usomwbgxot\n',
 'gkliazsibc\n',
 'exouzpyfaz\n',
 'scljkomqwp\n',
 'bcgiuamxek\n',
 'qpbepatnlq\n',
 'cyyqwxprae\n',
 'izkfytpeby\n',
 'jfynhxawts\n',
 'dcgdzixhde\n',
 'gztzhvuwva\n',
 'zzigsgyfyd\n',
 'xygtiulzyj\n',
 'qtsznbnjjw\n',
 'ymbfqjbwjp\n',
 'touecyuftz\n',
 'lfpriuekey\n',
 'kkbnnmmeyr\n',
 'bchkrrhfxo\n',
 'kdgqgicjib\n',
 'vxyeqseqtc\n',
 'iyyylrntac\n',
 'nlognbwqjf\n',
 'ljrleuhzeu\n',
 'daejwzpdgz\n',
 'todtgqadup\n',
 'teogtzbnhx\n',
 'glfeiglykd\n',
 'mrdjaiwlzh\n',
 'fnhplfyptn\n',
 'pzjwzmadxj\n',
 'syvofbuykt\n',
 'okejdbdwbu\n',
 'mbuceaazmj\n',
 'qetauapoqo\n',
 'vcdomtumcn\n',
 'eiggksebax\n',
 'lkmspqxmqt\n',
 'vlbakltvci\n',
 'exqqomgfxk\n',
 'gzerusctry\n',
 'mnjkwyfunh\n',
 'tkxgjaujen\n',
 'hmeqdvlihb\n',
 'brzgjwtafv\n',
 'slxfdashea\n',
 'rwykgphhih\n',
 'rseidwnkye\n',
 'rwxtwemzah\n',
 'kxomrimhxj\n',
 'kurzuztxfk\n',
 'okzfnfmpqi\n',
 'xbmwrrintg\n',
 'lurysqvcul\n',
 'wzvokzjyvp\n',
 'cwdgwekpta\n',
 'bmvlylyhrb\n',
 'qikyvuughc\n',
 'pfilxylwlq\n',
 'yeurekrjym\n',
 'wreyzdzrhe\n',
 'bvzddfimis\n',
 'ddeiixmsam\n',
 'hmwfwddtqx\n',
 'xqukzzanil\n',
 'vkvrgdnvou\n',
 'zquiqhbpye\n',
 'yehyfmpdnl\n',
 'todeztfbql\n',
 'kptxtctfmg\n',
 'nlyonaieam\n',
 'ccdmvhedpn\n',
 'msyeaubqdd\n',
 'mvixkxjdny\n',
 'imgnxvqdrh\n',
 'grmtjvcpnq\n',
 'yokrdreghp\n',
 'ryfhtyscqn\n',
 'hiufzpxror\n',
 'iljhmvlvft\n',
 'paiwguzhra\n',
 'ijpacmnnxo\n',
 'xdhstwxwya\n',
 'bmtwkptyqa\n',
 'lrhylnwepz\n',
 'pfmnscvxhk\n',
 'zexccdzehq\n',
 'vawacxkbxl\n',
 'fymdezcgwd\n',
 'aolbzoodtb\n',
 'czkcgoyoya\n',
 'apwwdxjwyy\n',
 'slehnictsd\n',
 'tykohhuabe\n',
 'jmdafwpbey\n',
 'nhsbrhsmkn\n',
 'vvlnfonxuu\n',
 'jkxzqwiaoi\n',
 'zacbcewmey\n',
 'jcbnkwzxgg\n',
 'cepgucshvw\n',
 'wwepacdvdc\n',
 'bdpmckwpcz\n',
 'hlskwqdsgs\n',
 'qgitxmirqr\n',
 'dtqqeumczv\n',
 'icagrtujrs\n',
 'dcjcprgtiv\n',
 'siivvxcprt\n',
 'mifpvagemm\n',
 'ymewrfyfjr\n',
 'xqqfimsxjk\n',
 'exesyujcvh\n',
 'werseuxujc\n',
 'beyscvmbew\n',
 'xwpxrrnelj\n',
 'jjbshbxutp\n',
 'kjusagabvj\n',
 'ephnufilny\n',
 'kgqvajyxut\n',
 'bzlxnxtxrq\n',
 'dkcdtdwljx\n',
 'aeakytqfud\n',
 'rywbmtnpkq\n',
 'fnrldneyaj\n',
 'ieuxxuhqbu\n',
 'jbjoktnoan\n',
 'ujwgbmelvr\n',
 'vzgvvhdsiz\n',
 'wreeetecsv\n',
 'timfuptjmu\n',
 'xwvugiprnp\n',
 'ngudztqdkq\n',
 'dypphiljfd\n',
 'upphkyngma\n',
 'xabjwsjwgw\n',
 'qldmwdircr\n',
 'vblhhguzca\n',
 'zqzisqeuan\n',
 'madncaiubx\n',
 'qdmqwtfhbi\n',
 'abpgszocsm\n',
 'ejnbjgrzsf\n',
 'arryicoeuo\n',
 'zrqkvcnxgp\n',
 'higbwvrhbx\n',
 'gmcfhrdexs\n',
 'idybrzyjle\n',
 'xknesnfzcq\n',
 'uqhkxcfnij\n',
 'hzxmqymkod\n',
 'feutbdovvz\n',
 'tpsviydjra\n',
 'cbhzcqnrch\n',
 'xxhviwqajz\n',
 'tssgkvdmzz\n',
 'sqpdyxbcad\n',
 'vwqbzsxqtq\n',
 'ubpinoqxms\n',
 'mgpcgzuwlp\n',
 'giqxinzxwf\n',
 'esaiakugcq\n',
 'prmduqukou\n',
 'audsmbqbyo\n',
 'motczfcjzk\n',
 'ylzcnbtswe\n',
 'fabvmlhcxk\n',
 'eozfazjhdk\n',
 'oldakkkyhv\n',
 'dzbqvonapq\n',
 'jwjbwygopt\n',
 'aknropfuwz\n',
 'mwvteclovo\n',
 'smoqrcvucl\n',
 'imviknduil\n',
 'mrbyarhklz\n',
 'oezfbsbjtw\n',
 'zyngchaapv\n',
 'fmibgoyjfb\n',
 'ubblzmiyza\n',
 'vewijdovco\n',
 'rcendbctxn\n',
 'lzzebuczzb\n',
 'cbvaufgidz\n',
 'cnmjufffxi\n',
 'yiamhnogqu\n',
 'oddpdjnhpx\n',
 'fsqgiugofr\n',
 'ffrrbtiecx\n',
 'nyrjvpmizy\n',
 'gwykxgdldq\n',
 'ahnietdzvq\n',
 'prdajydzxz\n',
 'vvaqnrmphm\n',
 'ogdwyqtigd\n',
 'xruihgbevj\n',
 'hmjhcnebri\n',
 'nzpxaorecj\n',
 'oyjopoihlv\n',
 'bjxhkftkbq\n',
 'mzweliabjd\n',
 'wkpuhecbjy\n',
 'oeoqwfolux\n',
 'lwyfplldfy\n',
 'zuaufoirps\n',
 'qvmlbvgibh\n',
 'tdowhnauub\n',
 'gkdepcccet\n',
 'hepvdloxqs\n',
 'bqcqqwvuko\n',
 'drqdmrivoz\n',
 'yzyuugpuxo\n',
 'ougbgtoiio\n',
 'ouyyrhijjh\n',
 'uiotwhuxfn\n',
 'drwpbtrkdh\n',
 'vkavbwvopp\n',
 'ufoaxyuaxz\n',
 'eryyiolldy\n',
 'gpxkuapuuf\n',
 'pvirwxgivh\n',
 'esqhzkwkfa\n',
 'rgyonqsnsu\n',
 'kerxtngmpn\n',
 'difqexbskm\n',
 'qzrjrnhhhl\n',
 'upxklzugdd\n',
 'jimkinizii\n',
 'vypjqerzwk\n',
 'ecphtyernv\n',
 'pywtzegvws\n',
 'cblsqamzxy\n',
 'pwxqtveuje\n',
 'vhhatkqqfg\n',
 'tjypcqrtkm\n',
 'xnjhzyitdp\n',
 'sxyltuscnd\n',
 'udebdpcoif\n',
 'lwcuofraoa\n',
 'pfzjfjipfd\n',
 'wvqtaeujtg\n',
 'dzgmqbqvyx\n',
 'yodishqbzg\n',
 'maimorhdag\n',
 'xnntqqpvmi\n',
 'kwuqhatodg\n',
 'uuozgruyqb\n',
 'xmeoifoxzo\n',
 'rwmxcyrsiy\n',
 'ukqxxrwwyq\n',
 'zemrnalboe\n',
 'kbosirbgvq\n',
 'mhlgwbsrxq\n',
 'vsducxdkdz\n',
 'yeyglbbxjy\n',
 'fqqbvivreo\n',
 'uqixckicxr\n',
 'drvbnacuje\n',
 'datzqlrzsn\n',
 'nmzkmnnhre\n',
 'wztfiuwvfu\n',
 'hhqcdwdunu\n',
 'jxoevmsoem\n',
 'jkzkyqssdd\n',
 'axkpbpdvvy\n',
 'hbkgavzfnk\n',
 'nlecngaxpu\n',
 'ytiotuiity\n',
 'votrpvhbbv\n',
 'bgzmiwflgj\n',
 'qsplrzjmdv\n',
 'nwagredpbq\n',
 'tnkkjfwfxl\n',
 'mpaozengya\n',
 'tbmudcmouk\n',
 'ycdsityrkp\n',
 'hqieziwxge\n',
 'upvnxwhkcz\n',
 'wysnbntess\n',
 'hqvjlyvxhv\n',
 'staoavvpca\n',
 'jtewlgwjrd\n',
 'bbxzfukwiu\n',
 'bukjbiwqxw\n',
 'koxzsunkas\n',
 'xmxjmedwft\n',
 'nsrxheabcm\n',
 'dzweearyzh\n',
 'emsshkzmcs\n',
 'onlgkklwee\n',
 'okqjzlvlmv\n',
 'aqgfyvcihe\n',
 'qnougecify\n',
 'ogqyzeayuy\n',
 'stcftfisth\n',
 'zybkdooeyp\n',
 'nznxnskvhe\n',
 'zaikpcfoxd\n',
 'yjpdytrkyk\n',
 'zcnhcfyset\n',
 'zqhpziankz\n',
 'nksqhpwicp\n',
 'ociskmlvyy\n',
 'lcsyeimqww\n',
 'xexzbjfhaj\n',
 'ndjcfeenhl\n',
 'tafwvzigej\n',
 'cfoscqnnhs\n',
 'mqvtuhrgok\n',
 'lmqefefuir\n',
 'iumgluvmkh\n',
 'cfmkevktpl\n',
 'oibbutdhpi\n',
 'szojhesfxz\n',
 'ikswdddesf\n',
 'ntdopqannp\n',
 'qqtttpehym\n',
 'mfywtxjcuf\n',
 'kvkfsaedqd\n',
 'jhyjzwradm\n',
 'lohhkvxumy\n',
 'bujigfilhr\n',
 'bhibiagflo\n',
 'rcilhwuhyi\n',
 'ibgtphhjmr\n',
 'rtpylxyfgr\n',
 'omapbqtiyc\n',
 'qljpdrrfyo\n',
 'dugmxoafeg\n',
 'kwqtidixbl\n',
 'mvaazqzdqe\n',
 'cqdxbekprw\n',
 'ozxgkpyqzx\n',
 'rbuvrzinxe\n',
 'kacyyorleo\n',
 'vkjnaqqcqu\n',
 'prasijerdw\n',
 'ozqjdszjsp\n',
 'pokafkixlw\n',
 'aomcfzcntw\n',
 'frhbcixlkr\n',
 'iqavzjqlwo\n',
 'hbsabzkgqp\n',
 'wkxfjngddv\n',
 'yqxomdaxug\n',
 'otpcndifoo\n',
 'hmxornejlo\n',
 'tllrbuxmgp\n',
 'tduuekkzlb\n',
 'gcdzpklmzt\n',
 'yhfvaksjeh\n',
 'iaiyydemge\n',
 'hxisfpwzmi\n',
 'mkuwbpegkh\n',
 'rfjxlqzlnm\n',
 'fwzgvaldrh\n',
 'epmltslgjt\n',
 'gpbmeptonl\n',
 'sigzjyboep\n',
 'ujupbeletj\n',
 'kaslmlkwzo\n',
 'muiathmslh\n',
 'wtvhvvdrga\n',
 'ocbmvyzgjz\n',
 'myppotygte\n']


import time
 
def concat_with_add(word_list):
    concat = ''
    for word in word_list:
        concat += word
    return concat

def concat_with_join(word_list):
    return ''.join(word_list)


start = time.time()
concat_with_add(random_strings)
end = time.time()
time_add = end - start

start = time.time()
concat_with_join(random_strings)
end = time.time()
time_join = end - start
    
print(time_add)
print(time_join)
# Out:
# 0.0
# 0.0

# %% [markdown]
# Above, we learned that using the `+` operator to concatenate a lot of strings leads to very slow performance. However, when we measured the execution times, we did not get very different results:
#
# `0.044194936752319336 # Time with +
# 0.003394603729248047 # Time with list.join()`
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# We can easily see this happen by slightly changing our last example.


import time
 
def concat_with_add(word_list):
    concat = ''
    for word in word_list:
        concat += word
        temp = concat
    return concat

def concat_with_join(word_list):
    return ''.join(word_list)

start = time.time()
concat_with_add(random_strings)
end = time.time()
time_add = end - start

start = time.time()
concat_with_join(random_strings)
end = time.time()
time_join = end - start
    
print(time_add)
print(time_join)
# Out:
# 0.0010001659393310547
# 0.0

# %% [markdown]
# As we could see above, this simple change drastically increases the execution time of concatenating all strings using the + operator:
#
# `5.073133945465088    # Time with +
# 0.002851247787475586 # Time with list.join()`

# %% [markdown]
# If we divide 5.073 by 0.002 we get about 2536. This means that concatenating using the `+` operator was more than 2,500 times slower! The bottom line is we should use `list.join()` whenever we need to concatenate a large number of strings.
#
# In this file, we've learned:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Let's recap the time complexities that we know so far in a diagram:
#
# ![image.png](attachment:image.png)
#
# We have learned about linear time complexity, quadratic complexity, and now constant time complexity. We will learn about logarithmic complexity and the binary search algorithm, which is an efficient algorithm to find elements in sorted lists.
